# %%
from IPython.display import display, HTML, Image, clear_output
import time
import random
#import time
#import ipywidgets as widgets
#from IPython.display import display, clear_output, HTML
#from jupyter_ui_poll import ui_events

#event_info = {
 #   'type': '',
  #  'description': '',
   # 'time': -1
}
#def wait_for_event(timeout=-1, interval=0.001, max_rate=20, allow_interupt=True):    
 #   start_wait = time.time()
  #  event_info['type'] = ""
   # event_info['description'] = ""
    #event_info['time'] = -1

    #n_proc = int(max_rate*interval)+1
    
    #with ui_events() as ui_poll:
     #   keep_looping = True
      #  while keep_looping==True:
            # process UI events
       #     ui_poll(n_proc)

            # end loop if we have waited more than the timeout period
        #    if (timeout != -1) and (time.time() > start_wait + timeout):
         #       keep_looping = False
                
            # end loop if event has occured
          #  if allow_interupt==True and event_info['description']!="":
                keep_looping = False
                
            # add pause before looping
            # to check events again
           # time.sleep(interval)
    
    # return event description after wait ends
    # will be set to empty string '' if no event occured
    #return event_info

# this function lets buttons 
# register events when clicked
#def register_event(btn):
    # display button description in output area
    #event_info['type'] = "click"
   # event_info['description'] = btn.description
    #event_info['time'] = time.time()
    #return

# %%
# with the helper code above we can
# add buttons 
# following the example below
#shape buttons
btn1 = widgets.Button(description="circle")
btn2 = widgets.Button(description="triangle")
btn3 = widgets.Button(description="square")
btn4 = widgets.Button(description="rhombus")
btn5 = widgets.Button(description="hexagon")
btn6 = widgets.Button(description="oval")
btn7 = widgets.Button(description="happy face")
btn8 = widgets.Button(description="microscope")
btn9 = widgets.Button(description="up arrow")
btn10 = widgets.Button(description="butterfly")
btn11 = widgets.Button(description="pound")
btn12 = widgets.Button(description="boy")
btn13 = widgets.Button(description="girl")
btn14 = widgets.Button(description="21")
btn15 = widgets.Button(description="3")
btn16 = widgets.Button(description="ethanol")
btn17 = widgets.Button(description="bromine")

shape_btns1 = widgets.HBox([btn1, 
btn2 ,
btn3 ,
btn4])
                           
shape_btns2 = widgets.HBox([btn5 ,
btn6 ,
btn7 ,
btn8] )
shape_btns3 = widgets.HBox([btn9 ,
btn10,
btn11,
btn12])
shape_btns4 = widgets.HBox([btn13,
btn14,
btn15,
btn16,
btn17])
panel1=widgets.VBox([shape_btns1, shape_btns2, shape_btns3, shape_btns4])

#colour buttons
btn18 = widgets.Button(description="yellow")
btn19 = widgets.Button(description="red")
btn20 = widgets.Button(description="black")
btn21 = widgets.Button(description="blue")
btn22 = widgets.Button(description="pink")
btn23 = widgets.Button(description="green")
btn24 = widgets.Button(description="grey")
btn25 = widgets.Button(description="purple")

color_btns1 = widgets.HBox([btn18, 
btn19 ,
btn20 ,
btn21])
                           
color_btns2 = widgets.HBox([btn22 ,
btn23 ,
btn24 ,
btn25] )
panel2=widgets.VBox([color_btns1, color_btns2])

#direction button
btn26 = widgets.Button(description="up")
btn27 = widgets.Button(description="down")
btn28 = widgets.Button(description="left")
btn29 = widgets.Button(description="right")

direction_btns1 = widgets.HBox([btn26 ,
btn27 ,
btn28 ,
btn29] )
panel3=widgets.VBox([direction_btns1])


#numer buttons
btn30 = widgets.Button(description="2")
btn31 = widgets.Button(description="3")
btn32 = widgets.Button(description="1")
btn33 = widgets.Button(description="0")

number_btns1 = widgets.HBox([btn30 ,
btn31 ,
btn32 ,
btn33] )
panel4=widgets.VBox([number_btns1])


    
# we need to set up each button
# to call the register_event
# function when clicked
panel1.on_click(register_event) 
panel2.on_click(register_event) 
panel3.on_click(register_event) 
panel4.on_click(register_event) 


myhtml1 = HTML("<h1>How do you feel today?</h1>")
display(myhtml1)
myhtml2 = HTML("<h2>You have 5 seconds to answer</h2>")
display(myhtml2)

#panel = widgets.HBox([btn1, btn2, btn3])
display(panel)

result = wait_for_event(timeout=5)
clear_output()

if result['description']!="":
    print(f"User clicked: {result['description']}")
else:
    print("User did not click in time")
# Out:
# User did not click in time

# %%
memory1 = Image ("Picture1.png", width = 500)
memory2 = Image ("Picture2.png", width = 500)
memory3 = Image ("Picture3.png", width = 500)
memory4 = Image ("Picture4.png", width = 500)
memory5 = Image ("Picture5.png", width = 500)
memory6 = Image ("Picture6.png", width = 500)
q_image1 = Image ("Picture7.png", width = 500)
q_image2 = Image ("Picture8.png", width = 500)
q_image3 = Image ("Picture9.png", width = 500)

# %%
question_list_1 = [
    {'q' :"What is the left shape?",
     'a': "triangle"},
    
    {'q':"What is the middle shape?", 
     'a':"circle"},
    
    {'q':"What is the right shape?", 
     'a':"square"}
    ]
all_question_list_1 = question_list_1.copy()
random.shuffle(all_question_list_1)
print(all_question_list_1)
# Out:
# [{'q': 'What is the left shape?', 'a': 'triangle'}, {'q': 'What is the middle shape?', 'a': 'circle'}, {'q': 'What is the right shape?', 'a': 'square'}]

# %%
def run_memory_test1():
    start_time = time.time()
    display(memory1)
    time.sleep(2)
    clear_output(wait=False)
    
    total_time1 = 0
    n_correct1 = 0 
        
    n1=len(all_question_list_1)
    for i in range(n1):
        q_dict = all_question_list_1[i]
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct1 = n_correct1 + 1
            e = n_correct1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time1 = total_time1 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time1:.2f} seconds")
    print(f"You gave {n_correct1} correct answers out of {n1}")
    return n_correct1
    return total_time1

# %%
question_list_2 = [
    {'q' :"What is pink?",
     'a': "rhombus"},
     {'q':"What is the bottom middle shape?", 
      'a':"triangle"},
     {'q':"What is grey?", 
       'a':"square"},
     {'q':"What color is pentagon?", 
      'a':"yellow"},
     {'q':"What color is circle?", 
       'a':"red"},
     {'q':"What is blue?",
       'a':"hexagon"}]

all_question_list_2 = question_list_2.copy()
random.shuffle(all_question_list_2)
print(all_question_list_2)
# Out:
# [{'q': 'What is blue?', 'a': 'hexagon'}, {'q': 'What color is pentagon?', 'a': 'yellow'}, {'q': 'What color is circle?', 'a': 'red'}, {'q': 'What is grey?', 'a': 'square'}, {'q': 'What is the bottom middle shape?', 'a': 'triangle'}, {'q': 'What is pink?', 'a': 'rhombus'}]

# %%
def run_memory_test2():
    start_time = time.time()
    display(memory2)
    time.sleep(3)
    clear_output(wait=False)
    
    total_time2 = 0
    n_correct2 = 0 
        
    n2=len(all_question_list_2)
    for i in range(n2):
        q_dict = all_question_list_2[i]
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct2 = n_correct2 + 1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time2 = total_time2 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time2:.2f} seconds")
    print(f"You gave {n_correct2} correct answers out of {n2}")
    return n_correct2
    return total_time2

# %%
question_list_3 = [
    {'q':"What color is apple?",
     'a':"red"},
    {'q':"What color are tubes?",
      'a':"blue"},
    {'q':"What color is bee?",
      'a':"pink"},
    {'q':"What is purple?",
      'a':"triangle"},
    {'q':"What color is beaker?",
     'a':"pink"},
    {'q':"What is green?",
     'a':"microscope"}]
all_question_list_3 = question_list_3.copy()
random.shuffle(all_question_list_3)
print(all_question_list_3)
# Out:
# [{'q': 'What color is bee?', 'a': 'pink'}, {'q': 'What is purple?', 'a': 'triangle'}, {'q': 'What color are tubes?', 'a': 'blue'}, {'q': 'What color is beaker?', 'a': 'pink'}, {'q': 'What is green?', 'a': 'microscope'}, {'q': 'What color is apple?', 'a': 'red'}]

# %%
def run_memory_test3():
    start_time = time.time()
    display(memory3)
    time.sleep(2)
    clear_output(wait=False)
    
    total_time3 = 0
    n_correct3 = 0 
        
    n3=len(all_question_list_3)
    for i in range(n3):
        q_dict = all_question_list_3[i]
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct3 = n_correct3 + 1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time_3 = total_time3 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time3:.2f} seconds")
    print(f"You gave {n_correct3} correct answers out of {n3}")
    return n_correct3
    return total_time3

# %%
question_list_4 = [
    {'q':"What is black?", 
     'a':"pound"},
     {'q':"What color is sad face?",
      'a':"blue"},
     {'q':"What is orange?", 
      'a':"happy face"},
     {'q':"What is yellow?", 
      'a':"butterfly"},
     {'q':"What color is atom?",
      'a':"green"},
     {'q':"What is pink?", 
      'a':"oval"},
     {'q':"What color is down arrow?",
      'a':"blue"},
     {'q':"What color is right arrow?",
      'a':"grey"},
     {'q':"What is red?",
      'a':"up arrow"}]
all_question_list_4 = question_list_4.copy()
random.shuffle(all_question_list_4)
print(all_question_list_4)
# Out:
# [{'q': 'What is pink?', 'a': 'oval'}, {'q': 'What is red?', 'a': 'up arrow'}, {'q': 'What color is down arrow?', 'a': 'blue'}, {'q': 'What is orange?', 'a': 'happy face'}, {'q': 'What is yellow?', 'a': 'butterfly'}, {'q': 'What is black?', 'a': 'pound'}, {'q': 'What color is atom?', 'a': 'green'}, {'q': 'What color is right arrow?', 'a': 'grey'}, {'q': 'What color is sad face?', 'a': 'blue'}]

# %%
def run_memory_test4():
    start_time = time.time()
    display(memory4)
    time.sleep(3)
    clear_output(wait=False)
    
    total_time4 = 0
    n_correct4 = 0 
        
    n4=len(all_question_list_4)
    for i in range(n4):
        q_dict = all_question_list_4[i]
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct4 = n_correct4 + 1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time4 = total_time4 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time4:.2f} seconds")
    print(f"You gave {n_correct4} correct answers out of {n4}")
    return n_correct4
    return total_time4

# %%
question_list_5 = [
    {'q':"What is black?", 
     'a':"21"},
     {'q':"What color is brain?",
      'a':"blue"},
     {'q':"What is orange?", 
      'a':"3"},
     {'q':"What is yellow?", 
      'a':"boy"},
     {'q':"What is green?",
      'a':"ethanol"},
     {'q':"What is pink?", 
      'a':"girl"},
     {'q':"What color is avocado?",
      'a':"purple"},
     {'q':"What color is methane?",
      'a':"red"},
     {'q':"What is brown?",
      'a':"bromine"}]
all_question_list_5 = question_list_5.copy()
random.shuffle(all_question_list_5)
print(all_question_list_5)
# Out:
# [{'q': 'What is orange?', 'a': '3'}, {'q': 'What is yellow?', 'a': 'boy'}, {'q': 'What color is brain?', 'a': 'blue'}, {'q': 'What is black?', 'a': '21'}, {'q': 'What color is methane?', 'a': 'red'}, {'q': 'What is brown?', 'a': 'bromine'}, {'q': 'What is green?', 'a': 'ethanol'}, {'q': 'What color is avocado?', 'a': 'purple'}, {'q': 'What is pink?', 'a': 'girl'}]

# %%
def run_memory_test5():
    start_time = time.time()
    display(memory5)
    time.sleep(3)
    clear_output(wait=False)
    
    total_time5 = 0
    n_correct5 = 0 
        
    n5=len(all_question_list_5)
    for i in range(n5):
        q_dict = all_question_list_5[i]
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct5 = n_correct5 + 1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time5 = total_time5 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time5:.2f} seconds")
    print(f"You gave {n_correct5} correct answers out of {n5}")
    return n_correct5, total_time5

# %%
question_list_6 = [
    {'q':"How many red arrows there are?", 
     'a':"2"},
     {'q':"Where does the arrow in here looks?",
      'a':"down"},
     {'q':"Where does the orange arrow look?", 
      'a':"up"},
     {'q':"What colour is this arrow?", 
      'a':"black"},
     {'q':"How many green arrows there are?",
      'a':"2"},
     {'q':"What colour is arrow right here?", 
      'a':"purple"},
     {'q':"Where does the yellow arrow look?",
      'a':"left"},
     {'q':"Where does the pink arrow look?",
      'a':"right"},
     {'q':"How many blue arrow there are?",
      'a':"2"}]
all_question_list_6 = question_list_6.copy()
random.shuffle(all_question_list_6)
print(all_question_list_6)
# Out:
# [{'q': 'Where does the orange arrow look?', 'a': 'up'}, {'q': 'What colour is this arrow?', 'a': 'black'}, {'q': 'Where does the yellow arrow look?', 'a': 'left'}, {'q': 'How many red arrows there are?', 'a': '2'}, {'q': 'What colour is arrow right here?', 'a': 'purple'}, {'q': 'How many blue arrow there are?', 'a': '2'}, {'q': 'How many green arrows there are?', 'a': '2'}, {'q': 'Where does the arrow in here looks?', 'a': 'down'}, {'q': 'Where does the pink arrow look?', 'a': 'right'}]

# %%
def run_memory_test6():
    start_time = time.time()
    display(memory6)
    time.sleep(5)
    clear_output(wait=False)
    
    total_time6 = 0
    n_correct6 = 0 
        
    n6=len(all_question_list_6)
    for i in range(n6):
        q_dict = all_question_list_6[i]
        if q_dict['q'] == f"Where does the arrow in here looks?":
               display(q_image1)
        elif  q_dict['q'] == f"What colour is this arrow?":
                display(q_image2)
        elif q_dict['q'] == f"What colour is arrow right here?":
               display(q_image3)
        ans = input(q_dict['q'])
        if ans==q_dict['a']:
            n_correct6 = n_correct6 + 1
    end_time = time.time()
        
    time_taken = end_time - start_time
    total_time6 = total_time6 + time_taken
        
    print("Well done!")
    time.sleep(1)
        
    print(f"You took {total_time6:.2f} seconds")
    print(f"You gave {n_correct6} correct answers out of {n6}")
    return n_correct6

# %%
from time import process_time
import time
tl_start = time.time()#process_time()
print("Welcome to the Memory test")
time.sleep(2)
print("You will be asked color/shape displayed in the image:")
time.sleep(2)
print("Be ready for the first image")
time.sleep(1)
clear_output(wait=False)
n_correct1=run_memory_test1()
time.sleep(3)
clear_output(wait=False)

print("Be ready for the second image")
time.sleep(2)
clear_output(wait=False)
n_correct2=run_memory_test2()
time.sleep(2)
clear_output(wait=False)

print("Be ready for the third image")
time.sleep(2)
clear_output(wait=False)
n_correct3=run_memory_test3()
time.sleep(2)
clear_output(wait=False)

print("Be ready for the forth image")
time.sleep(2)
clear_output(wait=False)
n_correct4=run_memory_test4()
time.sleep(2)
clear_output(wait=False)

print("Be ready for the fifth image")
time.sleep(1)
clear_output(wait=False)
n_correct1=run_memory_test5()
time.sleep(3)
clear_output(wait=False)

print ("Now you need to memorize different arrows")
time.sleep(2)
clear_output(wait=False)
print("Be ready for the sixth image")
time.sleep(2)
clear_output(wait=False)
n_correct6 = run_memory_test6()
time.sleep(2)
clear_output(wait=False)
tl_stop = time.time()

print("The total answering time in seconds:", tl_stop-tl_start-30)
total_test_score = n_correct1 + n_correct2 + n_correct3 + n_correct4 + n_correct5
total_qnumber = n1+ n2 + n3 + n4 + n5
print(f"Your total score for the memory test is {total_test_score} out of {total_qnumber}")
return total_test_score
from time import process_time
tl_start = process_time()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       9 time.sleep(1)
#      10 clear_output(wait=False)
# ---> 11 n_correct1=run_memory_test1()
#      12 time.sleep(3)
#      13 clear_output(wait=False)
#
# NameError: name 'run_memory_test1' is not defined

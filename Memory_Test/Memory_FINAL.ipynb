# %%
from IPython.display import display, Image, clear_output, HTML
import time
import random
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
from jupyter_ui_poll import ui_events
import requests
from bs4 import BeautifulSoup
import json

event_info = {
    'type': '',
    'description': '',
    'time': -1
}
def send_to_google_form(data_dict, form_url):
    ''' Helper function to upload information to a corresponding google form 
        You are not expected to follow the code within this function!
    '''
    form_id = form_url[34:90]
    view_form_url = f'https://docs.google.com/forms/d/e/{form_id}/viewform'
    post_form_url = f'https://docs.google.com/forms/d/e/{form_id}/formResponse'
    page = requests.get(view_form_url)
    content = BeautifulSoup(page.content, "html.parser").find('script', type='text/javascript')
    content = content.text[27:-1]
    result = json.loads(content)[1][1]
    form_dict = {}
    loaded_all = True
    for item in result:
        if item[1] not in data_dict:
            print(f"Form item {item[1]} not found. Data not uploaded.")
            loaded_all = False
            return False
        form_dict[f'entry.{item[4][0][0]}'] = data_dict[item[1]]
    post_result = requests.post(post_form_url, data=form_dict)
    return post_result.ok
    
def wait_for_event(timeout=-1, interval=0.001, max_rate=20, allow_interupt=True):    
    start_wait = time.time()
    event_info['type'] = ""
    event_info['description'] = ""
    event_info['time'] = -1
    n_proc = int(max_rate*interval)+1    
    with ui_events() as ui_poll:
        keep_looping = True
        while keep_looping==True:
            ui_poll(n_proc)
            if (timeout != -1) and (time.time() > start_wait + timeout):
                keep_looping = False
            if allow_interupt==True and event_info['description']!="":
                keep_looping = False
            time.sleep(interval)
    return event_info

def register_event(btn):
    event_info['type'] = "click"
    event_info['description'] = btn.description
    event_info['time'] = time.time()
    return
###########################################################################
memory1 = Image ("Picture1.png", width = 700)
memory2 = Image ("Picture2.png", width = 700)
memory3 = Image ("Picture3.png", width = 700)
memory4 = Image ("Picture4.png", width = 700)
memory5 = Image ("Picture5.png", width = 700)
memory6 = Image ("Picture6.png", width = 700)
memory7 = Image ("Picture7.png", width = 700)
memory8 = Image ("Picture8.png", width = 700)
memory9 = Image ("Picture9.png", width = 700)
img1 = Image ("Picture7.png", width = 700)
img2 = Image ("Picture8.png", width = 700)
img3 = Image ("Picture9.png", width = 700)


memory_list = [memory1, memory2, memory3, memory4, memory5, memory6, memory7, memory8, memory9]
#list of questions
question0 = "What is the left shape?"
question1 = "What is the middle shape?"
question2 = "What is the right shape?"
question6 = "What is pink?"
question7 = "What is the bottom middle shape?"
question8 = "What is grey?"
question9 = "What color is pentagon?"
question10 = "What color is circle?"
question11 = "What is blue?"
question12 = "What color is apple?"
question13 = "What color are tubes?"
question14 = "What color is bee?"
question15 = "What is purple?"
question16 = "What color is beaker?"
question17 = "What is green?"
question18 = "What is black?"
question19 = "What color is sad face?"
question20 = "What is orange?"
question21 = "What is yellow?"
question22 = "What color is atom?"
question23 = "What is pink?"
question24 = "What color is down arrow?"
question25 = "What color is right arrow?"
question26 = "What is red?"
question27 = "What is black?"
question28 = "What color is brain?"
question29 = "What is orange?"
question30 = "What is yellow?"
question31 = "What is green?"
question32 = "What is pink?"
question33 = "What color is avocado?"
question34 = "What color is methane?"
question35 = "What is brown?"
question36 = "How many red arrows there are?"
question37 = "Where does the orange arrow look?"
question38 = "How many green arrows there are?"
question39 = "Where does the yellow arrow look?"
question40 = "Where does the pink arrow look?"
question41 = "How many blue arrows there are?"
question42 = "Where does the arrow in here look?"
question43 = "What colour is this arrow?"
question44 = "What colour is the arrow here?"
#########################################################################
question_list = [question0,question1,question2,"/",

                 question6,question7,question8,question9,question10,question11,"/",

                 question12,question13,question14,question15,question16,question17,"/",

                 question18,question19,question20,question21,question22,question23,
                 question24,question25,question26,"/",
                 
                 question27,question28,question29,question30,question31,question32,
                 question33,question34,question35,"/",
                 
                 question36,question37,question38,question39,question40,question41,"/",
                 
                 question42,"/",
                 
                 question43,"/",
                 
                 question44,"/"]

#list of answers
answer_list = ["triangle","circle","square","/",
              "rhombus","triangle","square","yellow","red","hexagon","/",
              "red","blue","pink","triangle","pink","microscope","/",
              "pound","blue","happy face","butterfly","green","oval","blue","grey","up arrow","/",
              "21","blue","3","boy","ethanol","girl","purple","red","bromine","/",
              "2","up","2","left","right","2","/",
              "down","/",
               "black","/",
               "purple","/"]

#making buttons
#shapes
btn0 = widgets.Button(description="rhombus")
btn1 = widgets.Button(description="triangle")
btn2 = widgets.Button(description="circle")
btn3 = widgets.Button(description="square")
btn4 = widgets.Button(description="hexagon")
btn5 = widgets.Button(description="pentagon")
#colors
btn6 = widgets.Button(description="yellow")
btn7 = widgets.Button(description="red")
btn8 = widgets.Button(description="blue")
btn9 = widgets.Button(description="pink")
btn10 = widgets.Button(description="green")
btn11 = widgets.Button(description="grey")
btn12 = widgets.Button(description="purple")
btn13 = widgets.Button(description="black")
btn14 = widgets.Button(description="brown")
#numbers
btn15 = widgets.Button(description="1")
btn16 = widgets.Button(description="2")
btn17 = widgets.Button(description="3")
btn18 = widgets.Button(description="4")
#directions
btn19 = widgets.Button(description="up")
btn20 = widgets.Button(description="down")
btn21 = widgets.Button(description="left")
btn22 = widgets.Button(description="right")
#objects
btn23 = widgets.Button(description="microscope")
btn24 = widgets.Button(description="pound")
btn25 = widgets.Button(description="happy face")
btn26 = widgets.Button(description="butterfly")
btn27 = widgets.Button(description="oval")
btn28 = widgets.Button(description="up arrow")
btn29 = widgets.Button(description="21")
btn30 = widgets.Button(description="boy")
btn31 = widgets.Button(description="ethanol")
btn32 = widgets.Button(description="girl")

btn33 = widgets.Button(description="bromine")
btn34 = widgets.Button(description="3 test tubes")
btn35 = widgets.Button(description="beaker")
btn36 = widgets.Button(description="apple")
btn37 = widgets.Button(description="bee")
btn38 = widgets.Button(description="right arrow")
btn39 = widgets.Button(description="down arrow")
btn40 = widgets.Button(description="atom")
btn41 = widgets.Button(description="sad face")
btn42 = widgets.Button(description="brain")
btn43 = widgets.Button(description="pear")
btn44 = widgets.Button(description="methane")
#how buttons work
btn0.on_click(register_event)
btn1.on_click(register_event) 
btn2.on_click(register_event) 
btn3.on_click(register_event) 
btn4.on_click(register_event)
btn5.on_click(register_event) 
btn6.on_click(register_event) 
btn7.on_click(register_event) 
btn8.on_click(register_event)
btn9.on_click(register_event) 
btn10.on_click(register_event) 
btn11.on_click(register_event) 
btn12.on_click(register_event)
btn13.on_click(register_event) 
btn14.on_click(register_event) 
btn15.on_click(register_event) 
btn16.on_click(register_event) 
btn17.on_click(register_event) 
btn18.on_click(register_event)
btn19.on_click(register_event) 
btn20.on_click(register_event) 
btn21.on_click(register_event) 
btn22.on_click(register_event)
btn23.on_click(register_event) 
btn24.on_click(register_event) 
btn25.on_click(register_event) 
btn26.on_click(register_event)
btn27.on_click(register_event) 
btn28.on_click(register_event) 
btn29.on_click(register_event) 
btn30.on_click(register_event) 
btn31.on_click(register_event) 
btn32.on_click(register_event)
btn33.on_click(register_event) 
btn34.on_click(register_event) 
btn35.on_click(register_event)
btn36.on_click(register_event) 
btn37.on_click(register_event) 
btn38.on_click(register_event) 
btn39.on_click(register_event)
btn40.on_click(register_event) 
btn41.on_click(register_event) 
btn42.on_click(register_event) 
btn43.on_click(register_event) 
btn44.on_click(register_event)

s1 = widgets.HBox([btn0, btn1, btn2])
s2 = widgets.HBox([btn3,btn4,btn5])
c1 = widgets.HBox([btn6, btn7, btn8, btn9, btn10])
c2 = widgets.HBox([btn11,btn12, btn13, btn14])
i1_1 = widgets.HBox([btn23, btn24, btn25, btn26])
i1_2 = widgets.HBox([btn27, btn28, btn29, btn30])
i1_3 = widgets.HBox([btn31, btn32, btn33])
i2_1 = widgets.HBox([btn34, btn35, btn36, btn37])
i2_2 = widgets.HBox([ btn38, btn39, btn40, btn41])
i2_3 = widgets.HBox([btn42, btn43, btn44])

shapes = widgets.VBox([s1, s2])
colors = widgets.VBox([c1, c2])
items1 = widgets.VBox([i1_1, i1_2, i1_3])
items2 = widgets.VBox([i2_1, i2_2, i2_3])
numbers = widgets.HBox([btn15, btn16, btn17,btn18])
directions = widgets.HBox([btn19, btn20, btn21,btn22])


optionlist=[shapes,shapes,shapes,"/",
            shapes,shapes,shapes,colors,colors,shapes,"/",
            colors,colors,colors,shapes,colors,items1,"/",
            items1,colors,items1,items1,colors,items1,colors,colors,items1,"/",
            items1,colors,numbers,items1,items1,items1,colors,colors,items1,"/",
            numbers,directions,numbers,directions,directions,numbers, "/",
            directions, "/",
            colors, "/",
            colors, "/"]

data_consent_info = """DATA CONSENT INFORMATION:
Please read:
we wish to record your response data
to an anonymised public data repository.
Your data will be used for educational teaching purposes
practising data analysis and visualisation.

Please type yes in the box below if you consent to the upload."""
print(data_consent_info)
result = input("> ")
if result == "yes":
    print("Thanks for your participation.")
    print("Please contact philip.lewis@ucl.ac.uk")
    print("If you have any questions or concerns")
    print("regarding the stored results.")
else:
# end code execution by raising an exception
    raise(Exception("User did not consent to continue test."))
clear_output() 

id_instructions = """
Enter your anonymised ID
To generate an anonymous 4-letter unique user identifier please enter:
- two first letters (in capital) of your favoutite fruit
- two letters based on the initials (first and last name) of a favourite actor / actress

e.g. if your favoutite fruit is orange and favourite actor is Tom Cruise
then your unique identifer would be ORTC
"""
print(id_instructions)
user_id = input("> ")
print("User id:", user_id)
clear_output() 
ans1 = input("Enter your age:")
clear_output() 
ans2 = input("Enter your sex:")
clear_output() 

tl_start = time.time() #process_time()
print("Welcome to the Memory test")
time.sleep(2)
print("You will be asked color/shape displayed in the image:")
time.sleep(2)
print("Be ready for the first image")
time.sleep(2)
clear_output(wait=False)


def qrunner(sepe,x, correct_answer):
    if sepe < 45:
        display(memory_list[x])
        time.sleep(3)
        clear_output(wait=False)
    list_correct = []
    
    if sepe>(len(question_list)):
        myhtml4 = HTML("<h4>The test has finished</h4>")
        display(myhtml4)
    else:
        while question_list[sepe] != "/":
            print(question_list[sepe])
            if question_list[sepe] == question_list[45]:
                display(img1)
            elif question_list[sepe] == question_list[47]:
                display(img2)
            elif question_list[sepe] == question_list[49]:
                display(img3)
            display(optionlist[sepe])
            ans=answer_list[sepe]
            result = wait_for_event(timeout=9999)
            clear_output()
            
            if result['description']==ans:                    
                print ("correct")
                time.sleep(1)
                clear_output()      
                sepe=sepe+1 
                # list_correct.append(1)
                correct_answer += 1
            else:            
                print("incorrect")
                time.sleep(1)
                clear_output()
                sepe=sepe+1
                # list_correct.append(0)

        sepe=sepe+1
      
    return sepe, correct_answer

sep=0
correct_answer = 0
q1, correct_answer=qrunner(sep,0, correct_answer)
q2, correct_answer=qrunner(q1,1, correct_answer)
q3, correct_answer=qrunner(q2,2, correct_answer)
q4, correct_answer=qrunner(q3,3, correct_answer)
q5, correct_answer=qrunner(q4,4, correct_answer)
q6, correct_answer=qrunner(q5,5, correct_answer)
q7, correct_answer=qrunner(q6,6, correct_answer)
q8, correct_answer=qrunner(q7,7, correct_answer)
q9, correct_answer=qrunner(q8,8, correct_answer)
# print (q8)
# print (q8)

tl_stop = time.time()
tl_time = tl_stop-tl_start-11
print("The total answering time in seconds:", tl_time)
print(f"Your total score for the memory test is {correct_answer} out of {len(question_list)}")
#return correct_answer, tl_time
data=qrunner()
data_dict = {
'User id': user_id,
'age': ans1,
'sex': ans2,
'number of correct answers in test 1:': correct_answer[0],
'number of correct answers in test 2:':  correct_answer[1],
'number of correct answers in test 3:' : correct_answer[2],
'number of correct answers in test 4:' : correct_answer[3],
'number of correct answers in test 5:' : correct_answer[4],
'number of correct answers in test 6:' : correct_answer[5],
'total number of correct answers': correct_answer[-1],
'total time of the memory test:' : tl_time
}
form_url = 'https://docs.google.com/forms/d/1TeBTvrGEIWa_3rm794iM1GFFWAgpchrsfPyykFN-Gpg/edit?pli=1'

if datacollect=="y":
    send_to_google_form(data_dict,form_url)
# Out:
# The total answering time in seconds: 93.82769584655762
# Your total score for the memory test is 4 out of 51
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 388
#     386 print(f"Your total score for the memory test is {correct_answer} out of {len(question_list)}")
#     387 #return correct_answer, tl_time
# --> 388 data=qrunner()
#     389 data_dict = {
#     390 'User id': user_id,
#     391 'age': ans1,
#    (...)
#     400 'total time of the memory test:' : tl_time
#     401 }
#     402 form_url = 'https://docs.google.com/forms/d/1TeBTvrGEIWa_3rm794iM1GFFWAgpchrsfPyykFN-Gpg/edit?pli=1'
#
# TypeError: qrunner() missing 3 required positional arguments: 'sepe', 'x', and 'correct_answer'
